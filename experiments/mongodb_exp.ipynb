# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://chetangpande1_db_user:SNEjLGAxqfxHqyuP@ecom-pydanticai.qyzjmp0.mongodb.net/?appName=ecom-pydanticai")

# %%
db = client["ecom_db"]

collection = db["orders"]

print("connectted to mongo db")
# Out:
# connectted to mongo db

# %%
order = {
    "name": "Men Casual Shirt",
    "price": 999,
    "category": "men"
}

collection.insert_one(order)
# Out:
# InsertOneResult(ObjectId('69e4e77bf7c8e74556be9844'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🧪 🔹 CELL 6 — View All Products
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('69e4e77bf7c8e74556be9844'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('69e4e788f7c8e74556be9845'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69e4e788f7c8e74556be9846'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69e4e788f7c8e74556be9847'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('69e4e788f7c8e74556be9846'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "kids"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('69e4e788f7c8e74556be9847'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅
